# %%
import numpy as np
from icecream import ic
from Euler_1D import *
from Euler_2D import *
import pandas as pd
# %reload_ext autoreload
# %autoreload 1
# %aimport Euler_1D
# %aimport Euler_2D

# %% [markdown]
# Defining lists containing testing data

# %%
args_0 = {"space_len": 1.0, "x_0": 0.5, "N_div": 100, "gamma": 1.4, "time_len": 0.2, "rho_l": 1.0, "vel_l": 0.0, "press_l": 1.0, "rho_r": 0.125, "vel_r": 0.0, "press_r": 0.1, "const_C": 0.9}
args_1 = {"space_len": 1.0, "x_0": 0.3, "N_div": 100, "gamma": 1.4, "time_len": 0.2, "rho_l": 1.0, "vel_l": 0.75, "press_l": 1.0, "rho_r": 0.125, "vel_r": 0.0, "press_r": 0.1, "const_C": 0.9}
args_2 = {"space_len": 1.0, "x_0": 0.5, "N_div": 100, "gamma": 1.4, "time_len": 0.15, "rho_l": 1.0, "vel_l": -2.0, "press_l": 0.4, "rho_r": 1.0, "vel_r": 2.0, "press_r": 0.4, "const_C": 0.85}
args_3 = {"space_len": 1.0, "x_0": 0.5, "N_div": 100, "gamma": 1.4, "time_len": 0.012, "rho_l": 1.0, "vel_l": 0.0, "press_l": 1000.0, "rho_r": 1.0, "vel_r": 0.0, "press_r": 0.01, "const_C": 0.9}
args_4 = {"space_len": 1.0, "x_0": 0.4, "N_div": 100, "gamma": 1.4, "time_len": 0.035, "rho_l": 5.99924, "vel_l": 19.5975, "press_l": 460.894, "rho_r": 5.99242, "vel_r": -6.19633, "press_r": 46.095, "const_C": 0.9}
args_5 = {"space_len": 1.0, "x_0": 0.8, "N_div": 500, "gamma": 1.4, "time_len": 0.012, "rho_l": 1.0, "vel_l": -19.59745, "press_l": 1000.0, "rho_r": 1.0, "vel_r": -19.59745, "press_r": 0.01, "const_C": 0.9}

# %% [markdown]
# Plotting python sollution vs matlab sollution of Euler's equations in 1D for all test cases

# %%
plot_Steger_Warming_1D(save = "save_0.xlsx", **args_0)
# Out:
# 49

# %%
plot_Steger_Warming_1D(save = "save_1.xlsx", **args_1)

# %%
plot_Steger_Warming_1D(save = "save_2.xlsx", **args_2)

# %%
plot_Steger_Warming_1D(save = "save_3.xlsx", **args_3)

# %%
plot_Steger_Warming_1D(save = "save_4.xlsx", **args_4)

# %%
plot_Steger_Warming_1D(save = "save_5.xlsx", **args_5)

# %% [markdown]
# Plotting python vs matlab sollution of Euler's equations in 2D

# %%
x,y,t,w_whole = Roe_HH_2D(x_inter=(-1,1), y_inter=(-1,1), rho_ins=1, vel_x_ins=0, vel_y_ins=0, press_ins=1, rho_out=0.125,
                           vel_x_out=0, vel_y_out=0, press_out=0.1, radius=0.5, time_len=0.2, cons_C=0.85, gamma=1.4, Nx_div=60, Ny_div=60)

# %%
plot_Roe_HH(x,y,t,w_whole)
